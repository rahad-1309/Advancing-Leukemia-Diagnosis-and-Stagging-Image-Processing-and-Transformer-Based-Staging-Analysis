# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Import Libraries

# %%
! pip install tensorflow_addons
! pip install scikit-plot
# Out:
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: scikit-plot in /usr/local/lib/python3.10/dist-packages (0.3.7)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.11.3)
# Requirement already satisfied: joblib>=0.10 in /usr/local/lib/python3.10/dist-packages (from scikit-plot) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->scikit-plot) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)

# %%
import random
import os
import glob
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import plot_model
import tensorflow_addons as tfa

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report, precision_recall_fscore_support,
    accuracy_score, f1_score, matthews_corrcoef,
    confusion_matrix, ConfusionMatrixDisplay
)
from scikitplot.metrics import plot_roc
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# ## Hyper Parameters

# %%
class CFG:
    # DATA
    BUFFER_SIZE = 128
    BATCH_SIZE = 32
    HEIGHT = 224
    WIDTH = 224
    NUM_CLASSES = 4
    SEED = 42

    # AUGMENTATION
    IMAGE_SIZE = 224
    PATCH_SIZE = 8
    NUM_PATCHES = (IMAGE_SIZE // PATCH_SIZE) ** 2

    # OPTIMIZER
    LEARNING_RATE = 0.001
    WEIGHT_DECAY = 0.0001

    # TRAINING
    EPOCHS = 100

    # ARCHITECTURE
    INPUT_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)
    LAYER_NORM_EPS = 1e-6
    TRANSFORMER_LAYERS = 8
    PROJECTION_DIM = 64
    NUM_HEADS = 2
    TRANSFORMER_UNITS = [
        PROJECTION_DIM * 2,
        PROJECTION_DIM,
    ]
    MLP_HEAD_UNITS = [1024, 512]

# %% [markdown]
# ## Data Handling and loading

# %%
DATASET_PATH = '/content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/Original/'
# DATASET_PATH = '/content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/ALL_Segmented'

# %%
# Generate a summary of the dataset
print('DATASET SUMMARY')
print('========================\n')
for dirpath, dirnames, filenames in os.walk(DATASET_PATH):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}")
print('\n========================')
# Out:
# DATASET SUMMARY
# ========================
#
# There are 4 directories and 0 images in /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/Original/
# There are 0 directories and 804 images in /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/Original/Pro
# There are 0 directories and 985 images in /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/Original/Early
# There are 0 directories and 963 images in /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/Original/Pre
# There are 0 directories and 504 images in /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Dataset/Original/Benign
#
# ========================

# %%
image_path = []
for _dir in os.listdir(DATASET_PATH):
  _path = os.path.join(DATASET_PATH, _dir)
  for _img in os.listdir(_path):
    image_path.append(os.path.join(_path, _img))
image_path = sorted(image_path)

# %%
def generate_labels(image_paths):
    return [_.split('/')[-2:][0] for _ in image_paths]


def build_df(image_paths, labels):
    # Create dataframe
    df = pd.DataFrame({
        'image_path': image_paths,
        'label': generate_labels(labels)
    })

    # Generate label encodings
    # df['label_encoded'] = df.apply(lambda row: 0 if row.label == 'malignant' else 1, axis=1)

    # Shuffle and return df
    return df.sample(frac=1, random_state=CFG.SEED).reset_index(drop=True)

# %%
label = image_path[0].split('/')[-2:][0]
label
# Out:
# 'Benign'

# %%
images = build_df(image_path, generate_labels(image_path))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(images['label'])
images['label_encoding'] = le.transform(images['label'])

# %%
sorted(images['label'].unique())
# Out:
# ['Benign', 'Early', 'Pre', 'Pro']

# %%
def _load(image_path):
    # Read and decode an image file to a uint8 tensor
    image = tf.io.read_file(image_path)
    image = tf.io.decode_jpeg(image, channels=3)

    # Resize image
    image = tf.image.resize(image, [CFG.HEIGHT, CFG.WIDTH],
                            method=tf.image.ResizeMethod.LANCZOS5)

    # Convert image dtype to float32 and NORMALIZE!!!
    image = tf.cast(image, tf.float32)/255.

    # Return image
    return image

# %% [markdown]
# ## View Sample

# %%
def view_sample(image, label, color_map='rgb', fig_size=(6, 6)):
    plt.figure(figsize=fig_size)

    if color_map=='rgb':
        plt.imshow(image)
    else:
        plt.imshow(tf.image.rgb_to_grayscale(image), cmap=color_map)

    plt.title(f'Label: {label}', fontsize=16)
    return

# %%
# Select random sample from train_df
idx = random.sample(images.index.to_list(), 1)[0]

# Load the random sample and label
sample_image, sample_label = _load(images.image_path[idx]), images.label[idx]

# View the random sample
view_sample(sample_image, sample_label, color_map='rgb')

# %%
def view_mulitiple_samples(df, sample_loader, count=10, color_map='rgb', fig_size=(14, 10)):
    rows = count//5
    if count%5 > 0:
        rows +=1

    idx = random.sample(df.index.to_list(), count)
    fig = plt.figure(figsize=fig_size)

    for column, _ in enumerate(idx):
        plt.subplot(rows, 5, column+1)
        plt.title(f'Label: {df.label[_]}', pad=20)
        plt.axis('off')
        plt.subplots_adjust(wspace=0.005, hspace=0)

        if color_map=='rgb':
            plt.imshow(sample_loader(df.image_path[_]))
        else:
            plt.imshow(tf.image.rgb_to_grayscale(sample_loader(df.image_path[_])), cmap=color_map)

    plt.show()

    return

# view_mulitiple_samples(images, _load,
#                        count=25, color_map='rgb',
#                        fig_size=(20, 24))

# %% [markdown]
# ## Split train, valid, test

# %%
from sklearn.model_selection import train_test_split

train_x, valid_x, train_y, valid_y = train_test_split(images['image_path'], images['label_encoding'], test_size=0.2, random_state= CFG.SEED)
valid_x, test_x, valid_y, test_y = train_test_split(valid_x, valid_y, test_size=0.5, random_state=CFG.SEED)

# %% [markdown]
# ## View Dataset Distribution

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(14, 10))

# Set the spacing between subplots
fig.tight_layout(pad=6.0)

# Plot Train Labels Distribution
ax1.set_title('Train Labels Distribution', fontsize=20, pad=20)
train_distribution = train_y.value_counts().sort_values()
sns.barplot(x=train_distribution.values,
            y=list(train_distribution.keys()),
            orient="h",
            ax=ax1)

# Plot Test Labels Distribution
ax2.set_title('valid Labels Distribution', fontsize=20, pad=20)
test_distribution = valid_y.value_counts().sort_values()
sns.barplot(x=test_distribution.values,
            y=list(test_distribution.keys()),
            orient="h",
            ax=ax2);

sns.despine();

# %% [markdown]
# ## Augmentation

# %%
# Build augmentation layer
augmentation_layer = Sequential([
    layers.RandomFlip(mode='horizontal_and_vertical', seed=CFG.SEED),
    layers.RandomZoom(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1), seed=CFG.SEED),
    layers.RandomContrast(0.4, seed=CFG.SEED),

], name='augmentation_layer')

# %%
image = tf.image.rgb_to_grayscale(sample_image)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 8))

# Set the spacing between subplots
fig.tight_layout(pad=6.0)

# View Original Image
ax1.set_title('Original Image', fontsize=20, pad=20)
ax1.imshow(image, cmap='viridis');
ax1.axis('off')

# View Augmented Image
ax2.set_title('Augmented Image', fontsize=20, pad=20)
ax2.imshow(augmentation_layer(image), cmap='viridis');
ax2.axis('off')
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# ## Input Pipeline

# %%
def encode_labels(labels, encode_depth=CFG.NUM_CLASSES):
    return tf.one_hot(labels, depth=encode_depth).numpy()

def create_pipeline(X, y,  load_function, augment=False, batch_size=32, shuffle=False, cache=None, prefetch=False):
    '''
    Generates an input pipeline using the tf.data API given a Pandas DataFrame and image loading function.

    @params
        - X: X contain images path
        - y: y contain the label of corosponding X
        - load_function: (function) -> function used to load images given their paths
        - augment: (bool) -> condition for applying augmentation
        - batch_size: (int) -> size for batched (default=32)
        - shuffle: (bool) -> condition for data shuffling, data is shuffled when True (default=False)
        - cache: (str) -> cache path for caching data, data is not cached when None (default=None)
        - prefetch: (bool) -> condition for prefeching data, data is prefetched when True (default=False)

    @returns
        - dataset: (tf.data.Dataset) -> dataset input pipeline used to train a TensorFlow model
    '''
    # Get image paths and labels from DataFrame
    image_paths = X
    image_labels = encode_labels(y)
    AUTOTUNE = tf.data.AUTOTUNE

    # Create dataset with raw data from DataFrame
    ds = tf.data.Dataset.from_tensor_slices((image_paths, image_labels))

    # Map augmentation layer and load function to dataset inputs if augment is True
    # Else map only the load function
    if augment:
        ds = ds.map(lambda x, y: (augmentation_layer(load_function(x)), y), num_parallel_calls=AUTOTUNE)
    else:
        ds = ds.map(lambda x, y: (load_function(x), y), num_parallel_calls=AUTOTUNE)

    # Apply shuffling based on condition
    if shuffle:
        ds = ds.shuffle(buffer_size=1000)

    # Apply batching
    ds = ds.batch(batch_size)

    # Apply caching based on condition
    # Note: Use cache in memory (cache='') if the data is small enough to fit in memory!!!
    if cache != None:
        ds = ds.cache(cache)

    # Apply prefetching based on condition
    # Note: This will result in memory trade-offs
    if prefetch:
        ds = ds.prefetch(buffer_size=AUTOTUNE)

    # Return the dataset
    return ds

# %%
# Generate Train Input Pipeline
train_ds = create_pipeline(train_x, train_y, _load, augment=True,
                           batch_size=CFG.BATCH_SIZE,
                           shuffle=False, prefetch=True)

# Generate Validation Input Pipeline
val_ds = create_pipeline(valid_x, valid_y, _load,
                         batch_size=CFG.BATCH_SIZE,
                         shuffle=False, prefetch=False)

# Generate Test Input Pipeline
test_ds = create_pipeline(test_x, test_y, _load,
                          batch_size=CFG.BATCH_SIZE,
                          shuffle=False, prefetch=False)

# %%
# View string representation of datasets
print('========================================')
print('Train Input Data Pipeline:\n\n', train_ds)
print('========================================')
print('Validation Input Data Pipeline:\n\n', val_ds)
print('========================================')
# Out:
# ========================================
# Train Input Data Pipeline:
#
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>
# ========================================
# Validation Input Data Pipeline:
#
#  <_BatchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 4), dtype=tf.float32, name=None))>
# ========================================

# %% [markdown]
# # Model Running

# %% [markdown]
# ## Implement Shifted Patch Tokenization

# %%
def activation_block(x):
    x = layers.Activation("gelu")(x)
    return layers.BatchNormalization()(x)


def conv_stem(x, filters: int, patch_size: int):
    x = layers.Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return activation_block(x)


def conv_mixer_block(x, filters: int, kernel_size: int):
    # Depthwise convolution.
    x0 = x
    x = layers.DepthwiseConv2D(kernel_size=kernel_size, padding="same")(x)
    x = layers.Add()([activation_block(x), x0])  # Residual.

    # Pointwise convolution.
    x = layers.Conv2D(filters, kernel_size=1)(x)
    x = activation_block(x)

    return x


def get_conv_mixer_128_4(
    image_size=224, filters=128, depth=4, kernel_size=5, patch_size=2, num_classes=CFG.NUM_CLASSES
):

    inputs = tf.keras.Input((image_size, image_size, 3))

    # Extract patch embeddings.
    x = conv_stem(inputs, filters, patch_size)

    # ConvMixer blocks.
    for _ in range(depth):
        x = conv_mixer_block(x, filters, kernel_size)

    # Classification block.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return tf.keras.Model(inputs, outputs)

# %%
def run_experiment(model):
    paths = '/content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model'
    model_path = os.path.join(paths+"/files/", "convmixer.h5")
    csv_path = os.path.join(paths+"/files/", "convmixer.csv")
    #--------------------------------------------
    from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
    #--------------------------------------------------------
    # Define Early Stopping Callback
    early_stopping_callback = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=20,
        restore_best_weights=True)

    # (Optional) Define Reduce Learning Rate Callback
    # reduce_lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    #     monitor='val_loss',
    #     patience=6,
    #     factor=0.1,
    #     verbose=1)

    # Define Callbacks and Metrics lists
    CALLBACKS = [
            ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True),
            ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-10, verbose=1),
            CSVLogger(csv_path),
            EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
        ]

    METRICS = ['accuracy']

    # Compile the model
    model.compile(
        loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False,label_smoothing=0.0,axis=-1,reduction="auto",name="categorical_crossentropy",
    ),
        optimizer=tfa.optimizers.AdamW(learning_rate=CFG.LEARNING_RATE, weight_decay=CFG.WEIGHT_DECAY),
        metrics=METRICS
    )

    # Train the model
    print(f'Training {model.name}.')
    print(f'Train on {len(train_x)}, {len(train_y)} samples, validate on {len(valid_x)}, {len(valid_y)} samples.')
    print('----------------------------------')


    history = model.fit(
        train_ds,
        validation_data=val_ds,
        batch_size=CFG.BATCH_SIZE,
        epochs=CFG.EPOCHS,
        callbacks=CALLBACKS,
    )
    return history

# %%
model = get_conv_mixer_128_4()
history = run_experiment(model)
# Out:
# Training model.
# Train on 2604, 2604 samples, validate on 326, 326 samples.
# ----------------------------------
# Epoch 1/100
# 82/82 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8921
# Epoch 1: val_loss improved from inf to 1.43767, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 82/82 [==============================] - 383s 5s/step - loss: 0.3412 - accuracy: 0.8921 - val_loss: 1.4377 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 2/100
# 82/82 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9516
# Epoch 2: val_loss did not improve from 1.43767
# 82/82 [==============================] - 79s 963ms/step - loss: 0.1668 - accuracy: 0.9516 - val_loss: 1.8610 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 3/100
# 82/82 [==============================] - ETA: 0s - loss: 0.1178 - accuracy: 0.9639
# Epoch 3: val_loss did not improve from 1.43767
# 82/82 [==============================] - 79s 963ms/step - loss: 0.1178 - accuracy: 0.9639 - val_loss: 2.6927 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 4/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0956 - accuracy: 0.9708
# Epoch 4: val_loss did not improve from 1.43767
# 82/82 [==============================] - 81s 993ms/step - loss: 0.0956 - accuracy: 0.9708 - val_loss: 3.7277 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 5/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9785
# Epoch 5: val_loss did not improve from 1.43767
# 82/82 [==============================] - 79s 959ms/step - loss: 0.0690 - accuracy: 0.9785 - val_loss: 4.3587 - val_accuracy: 0.3282 - lr: 0.0010
# Epoch 6/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9820
# Epoch 6: val_loss did not improve from 1.43767
# 82/82 [==============================] - 79s 963ms/step - loss: 0.0549 - accuracy: 0.9820 - val_loss: 3.6929 - val_accuracy: 0.3650 - lr: 0.0010
# Epoch 7/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0578 - accuracy: 0.9808
# Epoch 7: val_loss did not improve from 1.43767
# 82/82 [==============================] - 79s 968ms/step - loss: 0.0578 - accuracy: 0.9808 - val_loss: 2.0315 - val_accuracy: 0.6196 - lr: 0.0010
# Epoch 8/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9881
# Epoch 8: val_loss improved from 1.43767 to 0.78430, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 80s 973ms/step - loss: 0.0405 - accuracy: 0.9881 - val_loss: 0.7843 - val_accuracy: 0.8344 - lr: 0.0010
# Epoch 9/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0342 - accuracy: 0.9885
# Epoch 9: val_loss did not improve from 0.78430
# 82/82 [==============================] - 78s 953ms/step - loss: 0.0342 - accuracy: 0.9885 - val_loss: 1.8010 - val_accuracy: 0.5736 - lr: 0.0010
# Epoch 10/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9827
# Epoch 10: val_loss did not improve from 0.78430
# 82/82 [==============================] - 79s 964ms/step - loss: 0.0528 - accuracy: 0.9827 - val_loss: 3.1733 - val_accuracy: 0.4571 - lr: 0.0010
# Epoch 11/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9896
# Epoch 11: val_loss improved from 0.78430 to 0.14822, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 82s 998ms/step - loss: 0.0382 - accuracy: 0.9896 - val_loss: 0.1482 - val_accuracy: 0.9448 - lr: 0.0010
# Epoch 12/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9892
# Epoch 12: val_loss did not improve from 0.14822
# 82/82 [==============================] - 79s 959ms/step - loss: 0.0305 - accuracy: 0.9892 - val_loss: 1.0651 - val_accuracy: 0.6687 - lr: 0.0010
# Epoch 13/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0321 - accuracy: 0.9885
# Epoch 13: val_loss did not improve from 0.14822
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0321 - accuracy: 0.9885 - val_loss: 4.1482 - val_accuracy: 0.3773 - lr: 0.0010
# Epoch 14/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9869
# Epoch 14: val_loss did not improve from 0.14822
# 82/82 [==============================] - 79s 964ms/step - loss: 0.0434 - accuracy: 0.9869 - val_loss: 3.3084 - val_accuracy: 0.4049 - lr: 0.0010
# Epoch 15/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9916
# Epoch 15: val_loss improved from 0.14822 to 0.13736, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 82s 998ms/step - loss: 0.0297 - accuracy: 0.9916 - val_loss: 0.1374 - val_accuracy: 0.9448 - lr: 0.0010
# Epoch 16/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0217 - accuracy: 0.9927
# Epoch 16: val_loss did not improve from 0.13736
# 82/82 [==============================] - 78s 953ms/step - loss: 0.0217 - accuracy: 0.9927 - val_loss: 1.3459 - val_accuracy: 0.6472 - lr: 0.0010
# Epoch 17/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9946
# Epoch 17: val_loss did not improve from 0.13736
# 82/82 [==============================] - 78s 957ms/step - loss: 0.0205 - accuracy: 0.9946 - val_loss: 1.3581 - val_accuracy: 0.6595 - lr: 0.0010
# Epoch 18/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 0.9965
# Epoch 18: val_loss improved from 0.13736 to 0.07508, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0152 - accuracy: 0.9965 - val_loss: 0.0751 - val_accuracy: 0.9785 - lr: 0.0010
# Epoch 19/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9939
# Epoch 19: val_loss did not improve from 0.07508
# 82/82 [==============================] - 79s 964ms/step - loss: 0.0189 - accuracy: 0.9939 - val_loss: 3.8128 - val_accuracy: 0.3037 - lr: 0.0010
# Epoch 20/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9927
# Epoch 20: val_loss did not improve from 0.07508
# 82/82 [==============================] - 78s 954ms/step - loss: 0.0257 - accuracy: 0.9927 - val_loss: 0.4909 - val_accuracy: 0.7761 - lr: 0.0010
# Epoch 21/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0276 - accuracy: 0.9904
# Epoch 21: val_loss did not improve from 0.07508
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0276 - accuracy: 0.9904 - val_loss: 7.2021 - val_accuracy: 0.5368 - lr: 0.0010
# Epoch 22/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9954
# Epoch 22: val_loss did not improve from 0.07508
# 82/82 [==============================] - 79s 961ms/step - loss: 0.0163 - accuracy: 0.9954 - val_loss: 1.8267 - val_accuracy: 0.6902 - lr: 0.0010
# Epoch 23/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0159 - accuracy: 0.9954
# Epoch 23: val_loss improved from 0.07508 to 0.02109, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 79s 961ms/step - loss: 0.0159 - accuracy: 0.9954 - val_loss: 0.0211 - val_accuracy: 0.9969 - lr: 0.0010
# Epoch 24/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9981
# Epoch 24: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 957ms/step - loss: 0.0095 - accuracy: 0.9981 - val_loss: 0.1440 - val_accuracy: 0.9509 - lr: 0.0010
# Epoch 25/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9981
# Epoch 25: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 969ms/step - loss: 0.0099 - accuracy: 0.9981 - val_loss: 5.6294 - val_accuracy: 0.3466 - lr: 0.0010
# Epoch 26/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0120 - accuracy: 0.9969
# Epoch 26: val_loss did not improve from 0.02109
# 82/82 [==============================] - 82s 995ms/step - loss: 0.0120 - accuracy: 0.9969 - val_loss: 2.6369 - val_accuracy: 0.5123 - lr: 0.0010
# Epoch 27/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9973
# Epoch 27: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 967ms/step - loss: 0.0117 - accuracy: 0.9973 - val_loss: 0.0470 - val_accuracy: 0.9877 - lr: 0.0010
# Epoch 28/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9950
# Epoch 28: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 957ms/step - loss: 0.0180 - accuracy: 0.9950 - val_loss: 5.6655 - val_accuracy: 0.3190 - lr: 0.0010
# Epoch 29/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9931
# Epoch 29: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 965ms/step - loss: 0.0188 - accuracy: 0.9931 - val_loss: 0.4368 - val_accuracy: 0.8957 - lr: 0.0010
# Epoch 30/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0127 - accuracy: 0.9962
# Epoch 30: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 961ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0543 - val_accuracy: 0.9877 - lr: 0.0010
# Epoch 31/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9973
# Epoch 31: val_loss did not improve from 0.02109
# 82/82 [==============================] - 80s 972ms/step - loss: 0.0084 - accuracy: 0.9973 - val_loss: 0.1019 - val_accuracy: 0.9663 - lr: 0.0010
# Epoch 32/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9950
# Epoch 32: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 963ms/step - loss: 0.0146 - accuracy: 0.9950 - val_loss: 1.8806 - val_accuracy: 0.6748 - lr: 0.0010
# Epoch 33/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9950
# Epoch 33: val_loss did not improve from 0.02109
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0136 - accuracy: 0.9950 - val_loss: 4.0019 - val_accuracy: 0.3957 - lr: 0.0010
# Epoch 34/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9981
# Epoch 34: val_loss did not improve from 0.02109
# 82/82 [==============================] - 79s 958ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0297 - val_accuracy: 0.9939 - lr: 1.0000e-04
# Epoch 35/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9981
# Epoch 35: val_loss improved from 0.02109 to 0.00663, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 80s 974ms/step - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0066 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 36/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9988
# Epoch 36: val_loss improved from 0.00663 to 0.00267, saving model to /content/drive/MyDrive/Research Paper/Health Science/Paper/Acute Lymphoblastic Leukemia/Model/files/convmixer.h5
# 82/82 [==============================] - 80s 976ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0027 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 37/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9988
# Epoch 37: val_loss did not improve from 0.00267
# 82/82 [==============================] - 81s 992ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.0042 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 38/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9996
# Epoch 38: val_loss did not improve from 0.00267
# 82/82 [==============================] - 78s 957ms/step - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.0029 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 39/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9992
# Epoch 39: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0046 - accuracy: 0.9992 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 40/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9988
# Epoch 40: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 961ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0059 - val_accuracy: 0.9969 - lr: 1.0000e-04
# Epoch 41/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 41: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 958ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 42/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 42: val_loss did not improve from 0.00267
# 82/82 [==============================] - 78s 951ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 43/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 43: val_loss did not improve from 0.00267
# 82/82 [==============================] - 78s 957ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 44/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9996
# Epoch 44: val_loss did not improve from 0.00267
# 82/82 [==============================] - 78s 952ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.0035 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 45/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 45: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 961ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Epoch 46/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 46: val_loss did not improve from 0.00267
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 82/82 [==============================] - 78s 945ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0237 - val_accuracy: 0.9939 - lr: 1.0000e-04
# Epoch 47/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 47: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 963ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 48/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9996
# Epoch 48: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 958ms/step - loss: 0.0049 - accuracy: 0.9996 - val_loss: 0.0030 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 49/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 49: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 956ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 50/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9992
# Epoch 50: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0034 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 51/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9996
# Epoch 51: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 959ms/step - loss: 0.0054 - accuracy: 0.9996 - val_loss: 0.0032 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 52/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 52: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 954ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 53/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9992
# Epoch 53: val_loss did not improve from 0.00267
# 82/82 [==============================] - 86s 1s/step - loss: 0.0058 - accuracy: 0.9992 - val_loss: 0.0036 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 54/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9996
# Epoch 54: val_loss did not improve from 0.00267
# 82/82 [==============================] - 80s 965ms/step - loss: 0.0062 - accuracy: 0.9996 - val_loss: 0.0037 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 55/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9988
# Epoch 55: val_loss did not improve from 0.00267
# 82/82 [==============================] - 79s 962ms/step - loss: 0.0070 - accuracy: 0.9988 - val_loss: 0.0038 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 56/100
# 82/82 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 56: val_loss did not improve from 0.00267
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 82/82 [==============================] - 78s 956ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000 - lr: 1.0000e-05

# %%
def visualization_plot(weights, idx=1):
    # First, apply min-max normalization to the
    # given weights to avoid isotrophic scaling.
    p_min, p_max = weights.min(), weights.max()
    weights = (weights - p_min) / (p_max - p_min)

    # Visualize all the filters.
    num_filters = 128
    plt.figure(figsize=(8, 8))

    for i in range(num_filters):
        current_weight = weights[:, :, :, i]
        if current_weight.shape[-1] == 1:
            current_weight = current_weight.squeeze()
        ax = plt.subplot(16, 16, idx)
        ax.set_xticks([])
        ax.set_yticks([])
        plt.imshow(current_weight)
        idx += 1


# We first visualize the learned patch embeddings.
patch_embeddings = model.layers[1].get_weights()[0]
visualization_plot(patch_embeddings)

# %% [markdown]
# # Performace Evaluation

# %%
# Generate model probabilities and associated predictions
test_probabilities = model.predict(val_ds, verbose=1)
test_predictions = tf.argmax(test_probabilities, axis=1)
# Out:
# 11/11 [==============================] - 3s 225ms/step

# %%
def plot_training_curves(history, ):

    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])

    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    epochs = range(len(history.history['loss']))

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10))

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='o')
    ax1.plot(epochs, val_loss, label='val_loss', marker='o')

    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)

    ax1.set_title('Loss (Lower Means Better)', fontsize=16)
    ax1.set_xlabel('Epochs', fontsize=12)
    ax1.legend()

    # Plot accuracy
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='o')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='o')

    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)

    ax2.set_title('Accuracy (Higher Means Better)', fontsize=16)
    ax2.set_xlabel('Epochs', fontsize=12)
    ax2.legend();

    sns.despine();

# %%
# plot vit model training history
plot_training_curves(history)

# %%
def plot_confusion_matrix(y_true, y_pred, classes='auto', figsize=(10, 10), text_size=12):
    # Generate confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Set plot size
    plt.figure(figsize=figsize)

    # Create confusion matrix heatmap
    disp = sns.heatmap(
        cm, annot=True, cmap='Greens',
        annot_kws={"size": text_size}, fmt='g',
        linewidths=0.1, linecolor='black', clip_on=False,
        xticklabels=classes, yticklabels=classes)

    # Set title and axis labels
    disp.set_title('Confusion Matrix', fontsize=24)
    disp.set_xlabel('Predicted Label', fontsize=20)
    disp.set_ylabel('True Label', fontsize=20)
    plt.yticks(rotation=0)

    # Plot confusion matrix
    plt.show()

    return

# %% [markdown]
# ## Validation Sets

# %%
class_names = ['Benign', 'Early', 'Pre', 'Pro']

plot_confusion_matrix(
    valid_y,
    test_predictions,
    figsize=(10, 10),
    classes=class_names)

# %%
plot_roc(valid_y,
         test_probabilities,
         figsize=(8, 8), title_fontsize='large');

# %%
print(classification_report(valid_y,
                            test_predictions,
                            target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       Benign       1.00      1.00      1.00        51
#        Early       1.00      1.00      1.00       107
#          Pre       1.00      1.00      1.00        89
#          Pro       1.00      1.00      1.00        79
#
#     accuracy                           1.00       326
#    macro avg       1.00      1.00      1.00       326
# weighted avg       1.00      1.00      1.00       326

# %%
def generate_preformance_scores(y_true, y_pred, y_probabilities):

    model_accuracy = accuracy_score(y_true, y_pred)
    model_precision, model_recall, model_f1, _ = precision_recall_fscore_support(y_true,
                                                                                 y_pred,
                                                                                 average="weighted")
    model_matthews_corrcoef = matthews_corrcoef(y_true, y_pred)

    print('=============================================')
    print(f'\nPerformance Metrics:\n')
    print('=============================================')
    print(f'accuracy_score:\t\t{model_accuracy:.4f}\n')
    print('_____________________________________________')
    print(f'precision_score:\t{model_precision:.4f}\n')
    print('_____________________________________________')
    print(f'recall_score:\t\t{model_recall:.4f}\n')
    print('_____________________________________________')
    print(f'f1_score:\t\t{model_f1:.4f}\n')
    print('_____________________________________________')
    print(f'matthews_corrcoef:\t{model_matthews_corrcoef:.4f}\n')
    print('=============================================')

    preformance_scores = {
        'accuracy_score': model_accuracy,
        'precision_score': model_precision,
        'recall_score': model_recall,
        'f1_score': model_f1,
        'matthews_corrcoef': model_matthews_corrcoef
    }
    return preformance_scores

# %%
# Record CCT model performance scores
performance = generate_preformance_scores(valid_y,
                                              test_predictions,
                                              test_probabilities)
# Out:
# =============================================
#
# Performance Metrics:
#
# =============================================
# accuracy_score:		1.0000
#
# _____________________________________________
# precision_score:	1.0000
#
# _____________________________________________
# recall_score:		1.0000
#
# _____________________________________________
# f1_score:		1.0000
#
# _____________________________________________
# matthews_corrcoef:	1.0000
#
# =============================================

# %% [markdown]
# ## Test Sets

# %%
# Generate model probabilities and associated predictions
test_probabilities = model.predict(test_ds, verbose=1)
test_predictions = tf.argmax(test_probabilities, axis=1)
# Out:
# 11/11 [==============================] - 43s 4s/step

# %%
class_names = ['Benign', 'Early', 'Pre', 'Pro']

plot_confusion_matrix(
    test_y,
    test_predictions,
    figsize=(10, 10),
    classes=class_names)

# %%
print(classification_report(test_y,
                            test_predictions,
                            target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#       Benign       1.00      0.98      0.99        51
#        Early       1.00      1.00      1.00       104
#          Pre       1.00      1.00      1.00        94
#          Pro       0.99      1.00      0.99        77
#
#     accuracy                           1.00       326
#    macro avg       1.00      1.00      1.00       326
# weighted avg       1.00      1.00      1.00       326

# %%
# Record CCT model performance scores
cct_performance = generate_preformance_scores(test_y,
                                              test_predictions,
                                              test_probabilities)
# Out:
# =============================================
#
# Performance Metrics:
#
# =============================================
# accuracy_score:		0.9969
#
# _____________________________________________
# precision_score:	0.9970
#
# _____________________________________________
# recall_score:		0.9969
#
# _____________________________________________
# f1_score:		0.9969
#
# _____________________________________________
# matthews_corrcoef:	0.9958
#
# =============================================
